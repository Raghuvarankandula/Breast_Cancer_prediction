# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cancer = pd.read_csv("cancer.csv")
cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
cancer.drop(["symmetry_worst","fractal_dimension_worst"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13688\2481152014.py in <cell line: 1>()
# ----> 1 cancer.drop(["symmetry_worst","fractal_dimension_worst"],axis=1,inplace=True)
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
cancer.drop("Unnamed: 32",axis=1,inplace=True)

# %%
cancer.drop(["concave points_worst","concavity_worst"],axis=1,inplace=True)
cancer.drop(["compactness_worst","smoothness_worst"],axis=1,inplace=True)
cancer.drop(["area_worst","perimeter_worst"],axis=1,inplace=True)
cancer.drop(["texture_worst","radius_worst"],axis=1,inplace=True)

# %%
cancer.hist(edgecolor='black',linewidth=1.2)
fig = plt.gcf()
fig.set_size_inches(12,6)
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(cancer.corr(),annot = True, cmap = "cubehelix_r")
plt.show()

# %%
cancer.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
plt.figure(figsize=(7,7))
sns.heatmap(cancer['radius_mean texture_mean perimeter_mean area_mean smoothness_mean diagnosis'.split()].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x = 'texture_mean', y = 'perimeter_mean', hue = 'diagnosis', data = cancer)
# Out:
# <AxesSubplot:xlabel='texture_mean', ylabel='perimeter_mean'>

# %%
train,test = train_test_split(cancer, test_size = 0.3)
print(train.shape)
print(test.shape)
# Out:
# (398, 22)
# (171, 22)

# %%
sns.FacetGrid(cancer, hue = 'diagnosis').map(plt.scatter,'texture_mean','perimeter_mean').add_legend()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

# %%
train_x = train[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
train_y = train.Species

test_x = test[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
test_y = test.Species
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13688\2356126574.py in <cell line: 1>()
# ----> 1 train_x = train[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
#       2 train_y = train.Species
#       3
#       4 test_x = test[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
#       5 test_y = test.Species
#
# NameError: name 'train' is not defined

# %%
#check how many values are missing (NaN)
#here we do not have any missing values
cancer.isnull().sum()
#handling categorical data
cancer['diagnosis'].unique()
cancer['diagnosis'] = cancer['diagnosis'].map({'B':0,'M':1})
cancer.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        NaN        17.99         10.38          122.80     1001.0
# 1    842517        NaN        20.57         17.77          132.90     1326.0
# 2  84300903        NaN        19.69         21.25          130.00     1203.0
# 3  84348301        NaN        11.42         20.38           77.58      386.1
# 4  84358402        NaN        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#visualizing diagnosis column >>> 'benign':0,'malignant':1
sns.countplot(x='diagnosis',data = cancer)
plt.title('number of Benign_0 vs Malignan_1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13688\3887723560.py in <cell line: 2>()
#       1 #visualizing diagnosis column >>> 'benign':0,'malignant':1
# ----> 2 sns.countplot(x='diagnosis',data = cancer)
#       3 plt.title('number of Benign_0 vs Malignan_1')
#
# ~\AppData\Roaming\Python\Python310\site-packages\seaborn\categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2937         raise ValueError("Cannot pass values for both `x` and `y`")
#    2938
# -> 2939     plotter = _CountPlotter(
#    2940         x, y, hue, data, order, hue_order,
#    2941         estimator, errorbar, n_boot, units, seed,
#
# ...

# %%
# correlation between features
cancer.corr()['diagnosis'][:-1].sort_values().plot(kind ='bar')
plt.title('Corr. between features and target')
# Out:
# Text(0.5, 1.0, 'Corr. between features and target')
